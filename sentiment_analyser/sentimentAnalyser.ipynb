# %%
# import the libraries

from textblob import TextBlob
from wordcloud import WordCloud
from textblob import classifiers
import pandas as pd
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/mabon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# with open('../data/data.csv', 'r') as csvfile:
#     reader = csv.reader(csvfile, delimiter=',')
#     output = list(reader)
    
# train_data_count = math.floor((len(output) * 0.8))
# train_data = []
# test_data = []

# for datapoint in output[1:train_data_count]:
#     train_data.append(tuple(datapoint))
    
# for datapoint in output[train_data_count:-1]:
#     test_data.append(tuple(datapoint))

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
# TESTING

# articles = pd.read_csv('../data/articleText.csv')
# articles['Subjectivity'] = articles['Article'].apply(getSubjectivity)
# articles['Polarity'] = articles['Article'].apply(getPolarity)
# articles.to_csv('../data/analysedArticleText.csv')

articles = pd.read_json('../data/referencerArray.json')
articles
# Out:
#                                               company  \
# 0   {'symbol': 'AMZN', 'name': 'Amazon', 'sector':...
# 1   {'symbol': 'AAPL', 'name': 'Apple', 'sector': ...
# 2   {'symbol': 'BRK.B', 'name': 'Berkshire Hathawa...
# 3   {'symbol': 'BA', 'name': 'Boeing', 'sector': '...
# 4   {'symbol': 'CME', 'name': 'CME Group', 'sector...
# 5   {'symbol': 'DAL', 'name': 'Delta Air Lines', '...
# 6   {'symbol': 'DOW', 'name': 'Dow', 'sector': 'Ma...
# 7   {'symbol': 'EBAY', 'name': 'eBay', 'sector': '...
# 8   {'symbol': 'FB', 'name': 'Facebook', 'sector':...
# 9   {'symbol': 'FDX', 'name': 'FedEx', 'sector': '...
# 10  {'symbol': 'GS', 'name': 'Goldman Sachs', 'sec...
# 11  {'symbol': 'INTC', 'name': 'Intel', 'sector': ...
# 12  {'symbol': 'JPM', 'name': 'JPMorgan Chase', 's...
# 13  {'symbol': 'MCD', 'name': 'McDonald's', 'secto...
# 14  {'symbol': 'MSFT', 'name': 'Microsoft', 'secto...
# 15  {'symbol': 'MRNA', 'name': 'Moderna', 'sector'...
# ...
